# %%
# %matplotlib inline
import os
import requests
import matplotlib
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

# %%
SALES = "http://archive.ics.uci.edu/ml/machine-learning-databases/00396/Sales_Transactions_Dataset_Weekly.csv"

# %%
def download_data(url, path='data'):
    if not os.path.exists(path):
        os.mkdir(path)

    response = requests.get(url)
    name = os.path.basename(url)
    with open(os.path.join(path, name), 'wb') as f:
        f.write(response.content)

# %%
download_data(SALES)

# %%
sales    = pd.read_csv('data/Sales_Transactions_Dataset_Weekly.csv', sep=",")

# %%
sales.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8      ...        \
# 0           P1  11  12  10   8  13  12  14  21   6      ...
# 1           P2   7   6   3   2   7   1   6   3   3      ...
# 2           P3   7  11   8   9  10   8   7  13  12      ...
# 3           P4  12   8  13   5   9   6   9  13  13      ...
# 4           P5   8   5  13  11   6   7   9  14   9      ...
#
#    Normalized 42  Normalized 43  Normalized 44  Normalized 45  Normalized 46  \
# 0           0.06           0.22           0.28           0.39           0.50
# 1           0.20           0.40           0.50           0.10           0.10
# 2           0.27           1.00           0.18           0.18           0.36
# 3           0.41           0.47           0.06           0.12           0.24
# 4           0.27           0.53           0.27           0.60           0.20
#
#    Normalized 47  Normalized 48  Normalized 49  Normalized 50  Normalized 51
# ...

# %%
sales.describe()
# Out:
#                W0          W1          W2          W3          W4          W5  \
# count  811.000000  811.000000  811.000000  811.000000  811.000000  811.000000
# mean     8.902589    9.129470    9.389642    9.717633    9.574599    9.466091
# std     12.067163   12.564766   13.045073   13.553294   13.095765   12.823195
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      3.000000    3.000000    3.000000    4.000000    4.000000    3.000000
# 75%     12.000000   12.000000   12.000000   13.000000   13.000000   12.500000
# max     54.000000   53.000000   56.000000   59.000000   61.000000   52.000000
#
#                W6          W7          W8          W9      ...        \
# count  811.000000  811.000000  811.000000  811.000000      ...
# mean     9.720099    9.585697    9.784217    9.681874      ...
# std     13.347375   13.049138   13.550237   13.137916      ...
# ...

# %%
X = sales[[
    "W0", "W1", "W2", "W3", "W4", "W5",
    "W6", "W7", "W8", "W9", "W10"
]]
y = sales["Product_Code"]

# %%
from yellowbrick.features import Rank2D

visualizer = Rank2D(algorithm="pearson")
visualizer.fit_transform(X)
visualizer.poof()

# %%
from yellowbrick.features import JointPlotVisualizer

visualizer = JointPlotVisualizer(feature='W5', target='W9')
visualizer.fit(X['W5'], X['W9'])
visualizer.poof()
